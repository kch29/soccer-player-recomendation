# %%
# %move /C:/Users/CHANHO KIM/Downloads/도로교통공단_사망 교통사고 정보_20201231.csv . 
# 윈도우에서는 해당 명령 실행 불가

# %%
# %pwd
# Out:
# 'c:\\ex_han\\file-path'

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: EAA2-41C0
#
#  c:\ex_han\file-path 디렉터리
#
# 2022-05-02  오후 08:11    <DIR>          .
# 2022-05-02  오후 07:58    <DIR>          ..
# 2022-05-02  오후 07:58    <DIR>          .ipynb_checkpoints
# 2022-05-02  오후 08:10               980 file-path-setting.ipynb
# 2022-05-02  오후 08:05           479,281 도로교통공단_사망 교통사고 정보_20201231.csv
#                2개 파일             480,261 바이트
#                3개 디렉터리  304,918,986,752 바이트 남음

# %%
import pandas as pd

# %%
pd.read_csv("data/도로교통공단_사망 교통사고 정보_20201231.csv", encoding ="cp949" )
# if -> UnicodeDecodeError : 위 파일의 인코딩이 UTF-8이 아니라는것 -> ()안에서 shift + tab 키를 눌러서 도움말 -> encoding을 지정해주자
# 보통 한글(엑셀)의 인코딩은 cp949/ euc-kr도 가능하지만 깨지는 한글 문자가 존재
# Out:
#        발생년         발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0     2020  2020-01-01 05  야  수     1     0     0     0       0    서울  ...
# 1     2020  2020-01-01 05  야  수     1     0     0     0       0    경기  ...
# 2     2020  2020-01-01 07  주  수     1     0     0     0       0    충남  ...
# 3     2020  2020-01-01 10  주  수     1     0     0     0       0    경남  ...
# 4     2020  2020-01-01 11  주  수     1     0     0     0       0    경기  ...
# ...    ...            ... .. ..   ...   ...   ...   ...     ...   ...  ...
# 2978  2020  2020-12-31 11  주  목     1     0     0     0       0    경기  ...
# 2979  2020  2020-12-31 18  야  목     1     0     0     0       0    세종  ...
# 2980  2020  2020-12-31 19  야  목     1     1     0     1       0    경남  ...
# 2981  2020  2020-12-31 21  야  목     1     0     0     0       0    경기  ...
# 2982  2020  2020-12-31 21  야  목     1     0     0     0       0    경기  ...
#
# ...
